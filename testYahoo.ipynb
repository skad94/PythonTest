# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
#cac= yf.Ticker("^FCHI")
#cac.info
sx5e= yf.download("^STOXX50E", start="2024-01-01", end ="2024-04-09")
#histo = sx5e.history(period='12mo')
#t = np.array(histo["Close"])
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
type(sx5e["Close"])
# Out:
# pandas.core.series.Series

# %%
sx5e["Close"].plot()
#plt.title(f"{ticker} Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
prenom = "Patrick"
print(" normale " + prenom)
print(f" f-string " + prenom)
# Out:
#  normale Patrick
#  f-string Patrick

# %%
# get all stock info
sx5e.info

# get historical market data
hist = sx5e.history(period="1mo")
hist.head()
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GOOGLE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GOOGLE&crumb=9w4VXOa6r3y
# GOOGLE: No data found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
np.mean(hist["Close"])
# Out:
# 171.77849960327148

# %%
def fun(x,y):
    return x+y

# %%
ticker1 = "GLE.PA"
ticker2 = "ACA.PA"
ticker3 = "BNP.PA"
ticker4 = "^STOXX50E"
ticker5 = "^FCHI"
#yf.download()
sg = yf.download(ticker1, start="2024-01-04",end="2024-04-04")
ca = yf.download(ticker2, start="2024-01-04",end="2024-04-04")
bnp = yf.download(ticker3, start="2024-01-04",end="2024-04-04")
sx5e = yf.download(ticker4, start="2024-01-04",end="2024-04-04")
cac = yf.download(ticker5, start="2024-01-04",end="2024-04-04")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
rr = sg["Close"]
print(type(rr))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#sg["Close"].name = "CA"
#rr.name('rre')
import pandas as pda
# Quick examples of add column name to series
rr = sg["Close"]
rr.rename("SG", inplace=True)
ee = ca["Close"]
ee.rename("CA", inplace=True)
vv = bnp["Close"]
vv.rename("BNP", inplace=True)
ww = sx5e["Close"]
ww.rename("SX5E", inplace=True)
qq = cac["Close"]
qq.rename("CAC", inplace=True)
yy = pda.DataFrame(rr,ee)

# Example 1: Add column name to Series
ser = pda.DataFrame(yy, columns = ['SG','CA'])

# Example 2: Add column name to Series
ser_df = pda.DataFrame(ser, columns = ['SG'])

# # Example 3: Add column name to Series
# ser_df3 = pda.DataFrame({'SG': ser.values})

# # Example 4: Add column name to Series
# ser_df3 = pda.DataFrame(ser).reset_index()
# ser_df3.columns = ['date', 'SG','CA']

# %%
ee
# Out:
# Date
# 2024-01-04    13.140
# 2024-01-05    13.250
# 2024-01-08    13.340
# 2024-01-09    13.318
# 2024-01-10    13.260
#                ...
# 2024-03-26    13.574
# 2024-03-27    13.580
# 2024-03-28    13.816
# 2024-04-02    13.875
# 2024-04-03    14.055
# Name: CA, Length: 63, dtype: float64

# %%
stok2 = pda.concat([rr, ee,vv,ww,qq], axis=1, names=['sg', 'Bfff', 'Cffff', 'Dffff', 'Effff'])
#stok3 = pda.DataFrame(stok2, columns = ["SG", "CA","BNP","SX5E","CAC"])
stok2.head()
# Out:
#                    SG      CA        BNP         SX5E          CAC
# Date
# 2024-01-04  24.350000  13.140  62.910000  4474.009766  7450.629883
# 2024-01-05  24.455000  13.250  63.000000  4463.509766  7420.689941
# 2024-01-08  24.684999  13.340  63.139999  4485.479980  7450.240234
# 2024-01-09  24.750000  13.318  62.630001  4467.169922  7426.620117
# 2024-01-10  24.424999  13.260  62.430000  4468.979980  7426.080078
