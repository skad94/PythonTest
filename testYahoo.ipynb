# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter( temps,concentration,marker ="o", color =" blue ")
plt.xlabel(" Temps ( h )")
plt.ylabel(" Concentration ( mg /L )")
plt.title(" Concentration de produit en fonction du temps ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.scatter( temps,concentration,marker ="o", color =" blue ")
#       2 plt.xlabel(" Temps ( h )")
#       3 plt.ylabel(" Concentration ( mg /L )")
#
# NameError: name 'temps' is not defined

# %%
#cac= yf.Ticker("^FCHI")
#cac.info
sx5e= yf.download("^STOXX50E", start="2023-01-01", end ="2024-04-09")
#histo = sx5e.history(period='12mo')
#t = np.array(histo["Close"])
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
type(sx5e["Close"])
# Out:
# pandas.core.series.Series

# %%
sx5e["Close"].plot()
#plt.title(f"{ticker} Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
prenom = "Patrick"
print(" normale " + prenom)
print(f" f-string " + prenom)
# Out:
#  normale Patrick
#  f-string Patrick

# %%
# show actions (dividends, splits)
print(type(apple))
# Out:
# <class 'yfinance.ticker.Ticker'>
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
# get all stock info
apple.info

# get historical market data
hist = apple.history(period="1mo")

# show meta information about the history (requires history() to be called first)
apple.history_metadata

# show actions (dividends, splits, capital gains)
apple.actions
apple.dividends
apple.splits
apple.capital_gains  # only for mutual funds & etfs

# show share count
apple.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
apple.income_stmt
apple.quarterly_income_stmt
# - balance sheet
apple.balance_sheet
apple.quarterly_balance_sheet
# - cash flow statement
apple.cashflow
apple.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
apple.major_holders
apple.institutional_holders
apple.mutualfund_holders
apple.insider_transactions
apple.insider_purchases
apple.insider_roster_holders

# show recommendations
apple.recommendations
apple.recommendations_summary
apple.upgrades_downgrades

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use apple.get_earnings_dates(limit=XX) with increased limit argument.
apple.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
apple.isin

# show options expirations
apple.options

# show news
apple.news

# get option chain for specific expiration
#opt = apple.option_chain('2024-02-07')
# data available via: opt.calls, opt.puts

# %%
# get all stock info
google.info

# get historical market data
hist = google.history(period="1mo")
hist.head()
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GOOGLE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GOOGLE&crumb=9w4VXOa6r3y
# GOOGLE: No data found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
np.mean(hist["Close"])
# Out:
# 171.77849960327148

# %%
Facebook= yf.Ticker("META")
Facebook.dividends
Facebook.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-03-11 00:00:00-04:00  497.010010  497.320007  476.000000  483.589996
# 2024-03-12 00:00:00-04:00  493.260010  502.309998  484.730011  499.750000
# 2024-03-13 00:00:00-04:00  495.390015  500.980011  491.029999  495.570007
# 2024-03-14 00:00:00-04:00  500.260010  501.350006  488.160004  491.829987
# 2024-03-15 00:00:00-04:00  489.010010  491.829987  481.299988  484.100006
# 2024-03-18 00:00:00-04:00  491.910004  497.420013  486.809998  496.980011
# 2024-03-19 00:00:00-04:00  488.170013  496.630005  481.279999  496.239990
# 2024-03-20 00:00:00-04:00  499.500000  508.200012  495.170013  505.519989
# 2024-03-21 00:00:00-04:00  514.710022  515.039978  506.010010  507.760010
# 2024-03-22 00:00:00-04:00  507.000000  509.970001  504.339996  509.579987
# 2024-03-25 00:00:00-04:00  505.790009  507.220001  500.239990  503.019989
# 2024-03-26 00:00:00-04:00  505.130005  510.000000  495.209991  495.890015
# ...
